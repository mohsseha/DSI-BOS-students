# %% [markdown]
# # wk2 5.1 lesson
# ## Independent Practice: Topic (20 minutes)
#
# Using the sales.csv data, do the following
#
# Create a stacked bar plot of Rep and Price
# Create a stacked bar plot of Rep and Quantity

# %%
import scipy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from scipy.stats import norm

# %%
sales = pd.read_csv("~/Documents/DSI-BOS-students/pparker-roach/Week 2/assets for lab 2.4/datasets/sales.csv")

# %%
print(sales.Name)
sales.keys()
# Out:
# 0                  Trantow-Barrows
# 1                  Trantow-Barrows
# 2                  Trantow-Barrows
# 3     Fritsch, Russel and Anderson
# 4                     Kiehn-Spinka
# 5                        Kulas Inc
# 6                        Kulas Inc
# 7                    Jerde-Hilpert
# 8                       Barton LLC
# 9                       Herman LLC
# 10                     Purdy-Kunde
# 11                      Stokes LLC
# 12                      Stokes LLC
# 13     Kassulke, Ondricka and Metz
# 14                     Keeling LLC
# 15                       Koepp Ltd
# 16                       Koepp Ltd
# Name: Name, dtype: object
# Index(['Account', 'Name', 'Rep', 'Manager', 'Product', 'Quantity', 'Price',
#        'Status'],
#       dtype='object')

# %%
sales_pivot1 = sales.pivot_table(index=["Rep"], columns=["Product"], values=["Price"], aggfunc=np.sum)
sales_pivot
# Out:
#               Quantity
# Product            CPU Maintenance Monitor Software
# Rep
# Cedric Moss        3.0         1.0     NaN      1.0
# Craig Booker       2.0         2.0     NaN      1.0
# Daniel Hilton      4.0         NaN     NaN      1.0
# John Smith         1.0         2.0     NaN      NaN
# Wendy Yule         7.0         3.0     2.0      NaN

# %%
ax1 = sales_pivot1.plot(kind='bar', stacked=True, title="Nice Title")
plt.show()

# %%
sales_pivot2 = sales.pivot_table(index=["Rep"], columns=["Product"], values=["Quantity"], aggfunc=np.sum)
sales_pivot
# Out:
#               Quantity
# Product            CPU Maintenance Monitor Software
# Rep
# Cedric Moss        3.0         1.0     NaN      1.0
# Craig Booker       2.0         2.0     NaN      1.0
# Daniel Hilton      4.0         NaN     NaN      1.0
# John Smith         1.0         2.0     NaN      NaN
# Wendy Yule         7.0         3.0     2.0      NaN

# %%
ax2 = sales_pivot2.plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(2,1,1) # two rows, one column, first plot
