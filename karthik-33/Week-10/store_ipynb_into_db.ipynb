# %%
import pandas as pd
import json

# %%
from pandas.io.json import json_normalize
import flatten_json

# %%
f = open("test.json").read()

# %%
fj = json.loads(f)

# %%
json_normalize(fj, "cells")
# Out:
#    cell_type  execution_count              metadata  \
# 0   markdown              NaN                    {}
# 1       code             68.0   {'collapsed': True}
# 2   markdown              NaN                    {}
# 3       code             69.0  {'collapsed': False}
# 4       code             57.0  {'collapsed': False}
# 5       code             58.0  {'collapsed': False}
# 6       code             59.0  {'collapsed': False}
# 7       code             60.0  {'collapsed': False}
# 8       code             61.0  {'collapsed': False}
# 9       code             62.0  {'collapsed': False}
# 10      code             63.0  {'collapsed': False}
# 11      code             64.0  {'collapsed': False}
# 12      code             65.0  {'collapsed': False}
# 13      code             66.0  {'collapsed': False}
# 14      code             67.0  {'collapsed': False}
# 15      code             70.0  {'collapsed': False}
# 16      code             71.0  {'collapsed': False}
# ...
