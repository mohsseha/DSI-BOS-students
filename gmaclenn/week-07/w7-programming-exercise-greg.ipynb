# %%
def str_to_int(string):
    roman_numeral_dict = {'I':1, 'V':5, 'X':10, 'L':50, 'C':100, 'D':500, 'M':1000}
    integer_value = 0
    for letter in string:
        letter_val = roman_numeral_dict[letter]
        if letter_val > integer_value:
            integer_value = letter_val - integer_value
        else:
            integer_value += letter_val
    return integer_value

# %%
def str_to_int(string):
    rn_table=[['M',1000],['CM',900],['D',500],['CD',400],['C',100],['XC',90],
               ['L',50],['XL',40],['X',10],['IX',9],['V',5],['IV',4],['I',1]]
    result = 0
    index = 0
    for numeral, integer in romanNumeralMap:
        while string[index:index+len(numeral)] == numeral:
            print len(numeral), index, string
            result += integer
            index += len(numeral)
    return result

str_to_int('XIX')
# Out:
# 1 0 XIX
# 2 1 XIX
# 19

# %%
def int_to_str(integer):
    rn_table=[['M',1000],['CM',900],['D',500],['CD',400],['C',100],['XC',90],
               ['L',50],['XL',40],['X',10],['IX',9],['V',5],['IV',4],['I',1]] 
    parts = []
    for letter, value in rn_table:
        # print letter, value, integer
        while value <= integer:
            # print "\t", integer, value
            integer -= value
            # print "\t\t", integer
            parts.append(letter)
            # print "\t\t", letter
    return ''.join(parts)
        
int_to_str(65)
# Out:
# 'LXV'

# %%
# do 10 spot checks
# then do a for loop from 1-1000 and do str_to_int(int_to_str()) = x
# in the for loop verify that what you put in gives the same output
# If this is not true you blow up and throw an exception.

# %%
from numpy.random import randint
random_list = []
for i in range(0,10):
    random_list.append(randint(1001))

random_list
# Out:
# [475, 108, 990, 101, 463, 44, 526, 497, 827, 727]

# %%
random_romans = []
for i in random_list:
     random_romans.append(int_to_str(i))

# %%
random_romans
# Out:
# ['CDLXXV',
#  'CVIII',
#  'CMXC',
#  'CI',
#  'CDLXIII',
#  'XLIV',
#  'DXXVI',
#  'CDXCVII',
#  'DCCCXXVII',
#  'DCCXXVII']

# %%
for i in range(1,1001):
    count = 0
    if str_to_int(int_to_str(i)) == i:
        pass
    else:
        count +=1
        print int_to_str(i)
        print str_to_int(int_to_str(i))
        print i, "There's an exception"
# Out:
# XIV
# 16
# 14 There's an exception
# XIX
# 21
# 19 There's an exception
# XXIV
# 26
# 24 There's an exception
# XXIX
# 31
# 29 There's an exception
# XXXIV
# 36
# 34 There's an exception
# XXXIX
# 41
# 39 There's an exception
# XLIV
# 46
# 44 There's an exception
# XLIX
# 51
# 49 There's an exception
# LIV
# 56
# 54 There's an exception
# LIX
# 61
# 59 There's an exception
# LXIV
# 66
# 64 There's an exception
# LXIX
# 71
# 69 There's an exception
# LXXIV
# 76
# 74 There's an exception
# LXXIX
# 81
# 79 There's an exception
# LXXXIV
# 86
# 84 There's an exception
# LXXXIX
# 91
# 89 There's an exception
# XCIV
# 96
# 94 There's an exception
# XCIX
# 101
# 99 There's an exception
# CIV
# 106
# 104 There's an exception
# CIX
# 111
# 109 There's an exception
# CXIV
# 116
# 114 There's an exception
# CXIX
# 121
# 119 There's an exception
# CXXIV
# 126
# 124 There's an exception
# CXXIX
# 131
# 129 There's an exception
# CXXXIV
# 136
# 134 There's an exception
# CXXXIX
# 141
# ...

# %%
#def int_to_str(integer):
    rom_num = []
    for i in roman_numeral_list:
        remainder = integer % float(i)
        if integer % i < integer:
            print "remainder {}, i: {}, integer {} ".format(remainder, i, integer)
            rom_num.append(roman_numeral_dict[i])
        elif remainder > 0:
            print 'r:', remainder
        elif remainder == 0:
            break
    return rom_num
            
int_to_str(650)
# Out:
# r: 650.0
# r: 650.0
# remainder 150.0, i: 500, integer 650
# remainder 250.0, i: 400, integer 650
# remainder 50.0, i: 100, integer 650
# remainder 20.0, i: 90, integer 650
# remainder 0.0, i: 50, integer 650
# remainder 10.0, i: 40, integer 650
# remainder 0.0, i: 10, integer 650
# remainder 2.0, i: 9, integer 650
# remainder 0.0, i: 5, integer 650
# remainder 2.0, i: 4, integer 650
# remainder 0.0, i: 1, integer 650
# ['D', 'CD', 'C', 'XC', 'L', 'XL', 'X', 'IX', 'V', 'IV', 'I']

# %%
#roman_numeral_list = [1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]
#roman_numeral_dict = {1000:'M', 900:'CM', 500:'D', 400:'CD', 100:'C', 90:'XC', 50:'L', 
                      40:'XL', 10:'X', 9:'IX', 5:'V', 4:'IV', 1:'I'}
# Out:
#   File "<ipython-input-136-f73451c6df54>", line 3
#     40:'XL', 10:'X', 9:'IX', 5:'V', 4:'IV', 1:'I'}
#     ^
# IndentationError: unexpected indent

# %%
romanNumeralMap = (('M',  1000),
                   ('CM', 900),
                   ('D',  500),
                   ('CD', 400),
                   ('C',  100),
                   ('XC', 90),
                   ('L',  50),
                   ('XL', 40),
                   ('X',  10),
                   ('IX', 9),
                   ('V',  5),
                   ('IV', 4),
                   ('I',  1))

def fromRoman(s):
    result = 0
    index = 0
    for numeral, integer in romanNumeralMap:
        while s[index:index+len(numeral)] == numeral:
            result += integer
            index += len(numeral)
    return result

fromRoman('VIX')
# Out:
# 6

# %%
# old code
#def int_to_str(integer):
    roman_numeral_dict = {1:'I', 5:'V', 10:'X', 50:'L', 100:'C', 500:'D', 1000:'M'}
    roman_numeral_list = [1000, 500, 100, 50, 10, 5, 1]
    for integer_keys in roman_numeral_list:
        if integer / integer_keys == 0:
            return roman_numeral_dict[integer]
        elif integer / integer_keys < 0:
            print integer / (integer_keys)
        else:
            return 'return'
        
#def int_to_str_2(integer):
    roman_numeral_dict = {1:'I', 5:'V', 10:'X', 50:'L', 100:'C', 500:'D', 1000:'M'}
    roman_numeral_list = [1000, 500, 100, 50, 10, 5, 1]
    for integer_keys in roman_numeral_list:
        if integer % integer_keys == 0:
            return roman_numeral_dict[integer]
        elif integer % integer_keys < 1:
            return 'return'
