# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./U.S._Chronic_Disease_Indicators__CDI_.csv")
# Out:
#     YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0        2013     2013           CA            California      YRBSS  Alcohol
# 1        2013     2013           CO              Colorado      YRBSS  Alcohol
# 2        2013     2013           CT           Connecticut      YRBSS  Alcohol
# 3        2013     2013           DC  District of Columbia      YRBSS  Alcohol
# 4        2013     2013           DE              Delaware      YRBSS  Alcohol
# 5        2013     2013           FL               Florida      YRBSS  Alcohol
# 6        2013     2013           GA               Georgia      YRBSS  Alcohol
# 7        2013     2013           GU                  Guam      YRBSS  Alcohol
# 8        2013     2013           HI                Hawaii      YRBSS  Alcohol
# 9        2013     2013           IA                  Iowa      YRBSS  Alcohol
# 10       2013     2013           ID                 Idaho      YRBSS  Alcohol
# ...

# %%
data.columns
# Out:
# Index([u'YearStart', u'YearEnd', u'LocationAbbr', u'LocationDesc',
#        u'DataSource', u'Topic', u'Question', u'Response', u'DataValueUnit',
#        u'DataValueTypeID', u'DataValueType', u'DataValue', u'DataValueAlt',
#        u'DataValueFootnoteSymbol', u'DatavalueFootnote', u'LowConfidenceLimit',
#        u'HighConfidenceLimit', u'StratificationCategory1', u'Stratification1',
#        u'StratificationCategory2', u'Stratification2',
#        u'StratificationCategory3', u'Stratification3', u'GeoLocation',
#        u'TopicID', u'QuestionID', u'ResponseID', u'LocationID',
#        u'StratificationCategoryID1', u'StratificationID1',
#        u'StratificationCategoryID2', u'StratificationID2',
#        u'StratificationCategoryID3', u'StratificationID3'],
#       dtype='object')

# %%
print(data["HighConfidenceLimit"][0:10])
print(np.mean(data["HighConfidenceLimit"]))
data["FilledHIGHCONFIDENCE"] = data["HighConfidenceLimit"].fillna(0)
#data["FilledHIGHCONFIDENCE"] = data["FilledHIGHCONFIDENCE"].astype(int)
print(max(data["FilledHIGHCONFIDENCE"]))
print(np.mean(data["FilledHIGHCONFIDENCE"]))

dropped_high_conf_interval = data[data["FilledHIGHCONFIDENCE"]<21]
print(max(dropped_high_conf_interval["FilledHIGHCONFIDENCE"]))
# Out:
# 0     NaN
# 1     NaN
# 2    41.0
# 3    32.5
# 4    39.0
# 5    36.6
# 6    32.3
# 7    27.0
# 8    28.8
# 9     NaN
# Name: HighConfidenceLimit, dtype: float64
# 74.2556917843
# 2088.0
# 44.1201026639
# 20.97

# %%
data['Topic'].value_counts()
# Out:
# Cardiovascular Disease                             43835
# Diabetes                                           37226
# Chronic Obstructive Pulmonary Disease              32704
# Overarching Conditions                             21569
# Asthma                                             18371
# Alcohol                                            15436
# Nutrition, Physical Activity, and Weight Status    14364
# Arthritis                                          12620
# Tobacco                                            11262
# Cancer                                              7001
# Chronic kidney disease                              6135
# Oral Health                                         5213
# Older Adults                                        3289
# Mental Health                                       2610
# Chronic Kidney Disease                              2058
# Immunization                                        1850
# ...

# %%
dental_data = data[data["Topic"]=="Oral Health"]


drop_dental_data = data[data["Topic"] !="Oral Health"]
print drop_dental_data["Topic"].value_counts()
# Out:
# Cardiovascular Disease                             43835
# Diabetes                                           37226
# Chronic Obstructive Pulmonary Disease              32704
# Overarching Conditions                             21569
# Asthma                                             18371
# Alcohol                                            15436
# Nutrition, Physical Activity, and Weight Status    14364
# Arthritis                                          12620
# Tobacco                                            11262
# Cancer                                              7001
# Chronic kidney disease                              6135
# Older Adults                                        3289
# Mental Health                                       2610
# Chronic Kidney Disease                              2058
# Immunization                                        1850
# Cardiovascular disease                              1548
# ...

# %%
drop_list = ['Cancer','Tobacco']
drop_tob_cac_data = data.drop(data.index[data["Topic"].isin(drop_list)])
print(drop_tob_cac_data["Topic"].value_counts())
# Out:
# Cardiovascular Disease                             43835
# Diabetes                                           37226
# Chronic Obstructive Pulmonary Disease              32704
# Overarching Conditions                             21569
# Asthma                                             18371
# Alcohol                                            15436
# Nutrition, Physical Activity, and Weight Status    14364
# Arthritis                                          12620
# Chronic kidney disease                              6135
# Oral Health                                         5213
# Older Adults                                        3289
# Mental Health                                       2610
# Chronic Kidney Disease                              2058
# Immunization                                        1850
# Cardiovascular disease                              1548
# Reproductive Health                                  815
# ...
