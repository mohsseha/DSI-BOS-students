# %%
import requests
import bs4
from urllib import urlopen
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
job_ids = []
descriptions = []
links = []

# %%
for i in np.arange(0,1000,10):
    URL = "https://www.indeed.com/jobs?q=data+scientist+$20,000&l=Boston&start={}&pp".format(str(i))
    #URL = "https://www.indeed.com/jobs?q=data+scientist+$20,000&l=Boston&start=10&pp"
    soup = BeautifulSoup(urlopen(URL).read(), 'html.parser')
    results = soup.find_all('div', attrs={'data-tn-component': 'organicJob'})
    for x in results:
        # get job_id
        job_id = x.find('h2', attrs={"class": "jobtitle"})['id']
        job_ids.append(job_id)
     
        # get job link
        link = "https://www.indeed.com" + x.find('h2', attrs={"class": "jobtitle"}).find('a')['href']
        links.append(link)    
            
        if 'rc/clk' in link:
            description = None
            descriptions.append(description)
        else:
            new_soup = BeautifulSoup(urlopen(link).read(), 'html.parser')
            description = new_soup.find('span', attrs = {'id': 'job_summary'}).text.strip()
            descriptions.append(description)

# %%
description_data = pd.DataFrame(columns = ['job_id','description','link'])
description_data['job_id'] = job_ids
description_data['description'] = descriptions
description_data['link'] = links

description_data.head(100)
# Out:
#                  job_id                                        description  \
# 0   jl_b59a64d3298e7fe8                                               None
# 1   jl_f43cd8061406b3d7                                               None
# 2   jl_fbadb59b5f73dc18                                               None
# 3   jl_ae7bb931f4c16e0b                                               None
# 4   jl_f5945f64ec7013e3                                               None
# 5   jl_70351b5092814475  You must apply at www.pfizercareers.com and se...
# 6   jl_50022587c7a4a8d9                                               None
# 7   jl_4fbc1d778df8203e                                               None
# 8   jl_44da2bd2b0b7e145                                               None
# 9   jl_04a882314da504d4  The PositionWe are looking for a Mass Spectrom...
# 10  jl_04a882314da504d4  The PositionWe are looking for a Mass Spectrom...
# 11  jl_85c4e91c561780aa                                               None
# 12  jl_b0b4a4c5be84240c                                               None
# 13  jl_6c9d0349b46d0aae  The client is looking for a Data Insights Anal...
# 14  jl_32062be6a68c7531                                               None
# 15  jl_e632343c455d80f9                                               None
# 16  jl_90603c7f1f0af480                                               None
# 17  jl_1b5a168dfc7b2712  DATA SCIENTISTAbout PrescribeWellnessWe believ...
# 18  jl_05654b2739edb3dc                                               None
# 19  jl_9315b3a96ad20ac0                                               None
# 20  jl_2370348e80d8c420                                               None
# 21  jl_1a7766c45b1abbeb                                               None
# 22  jl_2eb38474c0972c95                                               None
# 23  jl_1b5a168dfc7b2712  DATA SCIENTISTAbout PrescribeWellnessWe believ...
# 24  jl_54c0d6b8ad9f9e3d                                               None
# 25  jl_ada8a7b4477d3923  Senior Data/Computer Scientist/EngineerJob Des...
# 26  jl_2d63f589c7b4584b                                               None
# 27  jl_cccc5118af562f28                                               None
# 28  jl_b3462acabd0f43c3                                               None
# 98  https://www.indeed.com/rc/clk?jk=1eb955eee5c52...
# 99  https://www.indeed.com/rc/clk?jk=4d9c42761434f...
#
# [100 rows x 3 columns]

# %%
description_data.shape
# Out:
# (1000, 3)

# %%
# Only 131 out of 1000 jobs actually have a description on Indeed.com
description_data['description'].count()
# Out:
# 131

# %%
# But the good news is that the descriptions aren't that messy...
description_data['description'].iloc[9]
# Out:
# u'The PositionWe are looking for a Mass Spectrometry Data Analyst to join our growing team of Scientific Account Managers, supporting the expansion of our highly innovative software product Genedata Expressionist\xae, a comprehensive, enterprise-level software solution for mass spectrometry data processing, analysis, and management. The software addresses critical needs of research and development organizations seeking scalability and flexibility for a variety of applications, in particular in the field of biotherapeutics characterization.As part of our professional services team, you will act at the interface of science and business as a Mass Spectrometry Data Analyst, working closely with external customers as well as internal sales and development teams. We are looking for someone who is curious and inquisitive, with an ability to understand and present complex issues in a simple and rational way.This interdisciplinary, multi-faceted position offers an exciting opportunity to support, shape, and promote a successful, cutting-edge software solution. The position offers a high level of interactivity and responsibility in a growing company, and the opportunity to work as part of a strong international team.This full-time position is based at our office in Boston, MA. It requires about 20% travel within North America, and occasional travel to Europe.Key ResponsibilitiesSupport our users as a domain expert in mass spectrometry data analysisRespond to customer inquiries and troubleshooting requestsPlan and deliver training at customer sitesSupport our sales teams with product expertise, scientific presentations, and software demonstrationsIdentify customer needs, and map them to the capabilities of the softwareManage software installations and upgrades for customersDefine appropriate service projects with customers to fulfill unmet needsManage, execute, and deliver service projects for our customersCompile customer feedback and identify new analytical methods and solutions to address customers\u2019 challengesYour ProfileEssential Skills and Experience: Ph.D. in analytical sciences, bioinformatics, or related fields3+ years of relevant experience in mass spectrometry data analysisBackground in protein analysis and biotherapeutics characterization are highly desirableUnderstanding of statistics and familiarity with UNIX systems are a plusGood presentation abilities and excellent verbal and written communication skills in EnglishAbility to collaborate in a cross-functional environmentStrong initiative and dedication to quality of workLegal authorization to work in the United States on a full-time basis for any employer is required.The CompanyGenedata is an exceptional company. With nearly two decades of success in research informatics using closely-knit teams of scientists, developers and business experts, Genedata has achieved steady and continuous growth since inception. As a private and company, we focus on building our organization for the long-term and empower each employee to be a contributing voice in the company operations and evolution. Our collective expertise in research informatics, combined with our open and scalable computational solutions, makes us the leading software provider for R&D; in the pharma, biotech, and agricultural research industries. We are headquartered in Basel, Switzerland and have offices in Munich, Boston, San Francisco, and Tokyo.Are you interested?If you are interested in this position, please email your resume or your CV and your motivation letter to reference number BOS-EXP-SAM. Genedata is an Equal Opportunity Employer. Genedata only accepts CVs and resumes directly from candidates. Personnel recruitment agencies need not respond.Job Type: Full-timeJob Location:Boston, MARequired education:DoctorateRequired experience:Data Analyst: 3 years'
