# %%
import sqlite3

# %%
sqlite_db = "test_db.sqlite"
conn = sqlite3.connect(sqlite_db) # conn == connect
c = conn.cursor() # create a cursor

# %%
c.execute('CREATE TABLE houses (field1 INTEGER PRIMARY KEY, sqft INTEGER, bdrms INTEGER, age INTEGER, price INTEGER)')
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-2e18cac62652> in <module>()
# ----> 1 c.execute('CREATE TABLE houses (field1 INTEGER PRIMARY KEY, sqft INTEGER, bdrms INTEGER, age INTEGER, price INTEGER)')
#       2 conn.commit()
#
# OperationalError: table houses already exists

# %%
last_sale = (None, 4000, 5, 22, 619000)

# %%
c.execute('INSERT INTO houses VALUES (?,?,?,?,?)', last_sale)

# %%
conn.commit()

# %%
from numpy import genfromtxt

# %%
data = (genfromtxt('assets/datasets/housingdata.csv', dtype = 'i8', 
                   delimiter = ',', skip_header = 1)).tolist()
for d in data:
    d.insert(0, None) #makes all values in column 0 None, so the pks are autogenerated
    

c.execute('INSERT INTO houses VALUES (?,?,?,?,?)', data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-8bf42631c2c6> in <module>()
#       1 data = (genfromtxt('assets/datasets/housingdata.csv', dtype = 'i8',
# ----> 2                    delimiter = ',', skip_header = 1)).tolist()
#       3 for d in data:
#       4     d.insert(0, None) #makes all values in column 0 None, so the pks are autogenerated
#       5
#
# //anaconda/lib/python3.5/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1451                 fhd = iter(np.lib._datasource.open(fname, 'rbU'))
#    1452             else:
# -> 1453                 fhd = iter(np.lib._datasource.open(fname, 'rb'))
# ...
