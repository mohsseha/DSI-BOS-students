# %%
import pandas as pd

# %%
filepath = "/Users/Nathan/Downloads/ad43b834-435c-40ba-84d3-945ec4518fd5.csv"
raw_data = pd.read_csv(filepath)

# %%
print(raw_data.columns)
print(raw_data[0:3])
# Out:
# Index(['﻿"url"', 'Analytics image', 'Analytics image_alt',
#        'Analytics image_link', 'Searchresult value', 'Biznameclick link',
#        'Biznameclick link_link', 'Image', 'Image_alt', 'Reviewcount value',
#        'Categorylist content', 'Categorylist links', 'Categorylist links_link',
#        'Neighborhood value', 'Secondary value 1', 'Secondary value 2',
#        'Phonenumber label', 'Phonenumber number', 'Photobox image',
#        'Photobox image_alt', 'Photobox image_link', 'Snippet content',
#        'Readmore link', 'Readmore link_link'],
#       dtype='object')
#                                               ﻿"url"  \
# 0  https://www.yelp.com/search?find_desc=bay+area...
# 1  https://www.yelp.com/search?find_desc=bay+area...
# 2  https://www.yelp.com/search?find_desc=bay+area...
#
#                                      Analytics image  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/nYLNIq...
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/elyyyC...
# ...

# %%
data = raw_data.drop(raw_data[["Analytics image", "Analytics image_link", "Biznameclick link_link", "Image", "Categorylist links_link", "Photobox image", "Photobox image_link", "Readmore link", "Readmore link_link"]], axis = 1)
data.drop(data["Searchresult value"] == "Ad", inplace = True)
data
# Out:
#                                                ﻿"url"  \
# 2   https://www.yelp.com/search?find_desc=bay+area...
# 3   https://www.yelp.com/search?find_desc=bay+area...
# 4   https://www.yelp.com/search?find_desc=bay+area...
# 5   https://www.yelp.com/search?find_desc=bay+area...
# 6   https://www.yelp.com/search?find_desc=bay+area...
# 7   https://www.yelp.com/search?find_desc=bay+area...
# 8   https://www.yelp.com/search?find_desc=bay+area...
# 9   https://www.yelp.com/search?find_desc=bay+area...
# 10  https://www.yelp.com/search?find_desc=bay+area...
# 11  https://www.yelp.com/search?find_desc=bay+area...
# 12  https://www.yelp.com/search?find_desc=bay+area...
#
#                     Analytics image_alt Searchresult value  \
# 2                           Icon Dental                 1.
# 3          Union Square Dental Practice                 2.
# 4                      Claude Sidi, DMD                 3.
# 5                  Robert Phong Ho, DDS                 4.
# ...
