# %%
import pandas as pd

# %%
filepath = "https://en.wikipedia.org/wiki/Punxsutawney_Phil#Past_predictions"

raw_data = pd.read_html(filepath, header=0)[1]

# %%
data = raw_data.copy()

# %%
years = data["Year"].str.split("–", expand = True)
data["start_year"] = years[0]

# %%
# pd.concat([years[0], years[1]]).apply(pd.to_numeric, errors = 'coerce').dropna().sort_values()
data
# Out:
#          Year                                     Prediction[12] start_year
# 0   1887–1888                                      "Long winter"       1887
# 1        1889                                          No record       1889
# 2        1890                                     "Early spring"       1890
# 3   1891–1897                                          No record       1891
# 4        1898                                      "Long winter"       1898
# 5        1899                                          No record       1899
# 6   1900–1901                                      "Long winter"       1900
# 7        1902                                     "Early spring"       1902
# 8   1903–1933                                      "Long winter"       1903
# 9        1934                                     "Early spring"       1934
# 10  1935–1941                                      "Long winter"       1935
# ...
