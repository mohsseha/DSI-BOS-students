# %%
from functools import reduce
reduce(lambda d, c: d.update([(c, d.get(c,0)+1)]) or d, open('input.txt').read().split(), {})
# Out:
# {'All': 2,
#  'And': 5,
#  'And,': 1,
#  'Bandersnatch!”': 1,
#  'Beware': 1,
#  'Callay!”': 1,
#  'Callooh!': 1,
#  'Came': 1,
#  'Come': 1,
#  'Did': 2,
#  'He': 4,
#  'Jabberwock,': 2,
#  'Jabberwock?': 1,
#  'Jubjub': 1,
#  'Long': 1,
#  'O': 1,
#  'One,': 2,
#  'So': 1,
#  'The': 4,
#  'Tumtum': 1,
#  'and': 7,
#  'arms,': 1,
#  'as': 2,
#  'awhile': 1,
#  'back.': 1,
#  'beamish': 1,
#  'bird,': 1,
#  'bite,': 1,
#  'blade': 1,
#  'borogoves,': 2,
#  'boy!': 1,
#  'brillig,': 2,
#  'burbled': 1,
#  'by': 1,
#  'came!': 1,
#  'catch!': 1,
#  'chortled': 1,
#  'claws': 1,
#  'day!': 1,
#  'dead,': 1,
#  'eyes': 1,
#  'flame,': 1,
#  'foe': 1,
#  'frabjous': 1,
#  'frumious': 1,
#  'galumphing': 1,
#  'gimble': 2,
#  'gyre': 2,
#  'hand;': 1,
#  'hast': 1,
#  'he': 3,
#  'head': 1,
#  'his': 2,
#  'in': 6,
#  'it': 2,
#  'its': 1,
#  'jaws': 1,
#  'joy.': 1,
#  'left': 1,
#  'manxome': 1,
#  'mimsy': 2,
#  'mome': 2,
#  'my': 3,
#  'of': 1,
#  'outgrabe.': 2,
#  'raths': 2,
#  'rested': 1,
#  'shun': 1,
#  'slain': 1,
#  'slithy': 2,
#  'snicker-snack!': 1,
#  'son': 1,
#  'sought—': 1,
#  'stood': 1,
#  'stood,': 1,
#  'sword': 1,
#  'that': 2,
#  'the': 15,
#  'thou': 1,
#  'thought': 1,
#  'thought.': 1,
#  'through': 3,
#  'time': 1,
#  'to': 1,
#  'took': 1,
#  'toves': 2,
#  'tree,': 1,
#  'tulgey': 1,
#  'two!': 2,
#  'uffish': 1,
#  'vorpal': 2,
#  'wabe;': 2,
#  'went': 2,
#  'were': 2,
#  'whiffling': 1,
#  'with': 2,
#  'wood,': 1,
#  '‘Twas': 2,
#  '“And': 1,
#  '“Beware': 1}

# %%
import re
import string

frequency = {}
document_text = open('input.txt', 'r')
text_string = document_text.read().lower()
match_pattern = re.findall(r'\b[a-z]{3,15}\b', text_string)
 
for word in match_pattern:
    count = frequency.get(word,0)
    frequency[word] = count + 1
     
frequency_list = frequency.keys()
 
for words in frequency_list:
    print('{}\t{}'.format(words, frequency[words]))
# Out:
# gimble	2
# sword	1
# tulgey	1
# all	2
# foe	1
# uffish	1
# toves	2
# through	3
# bird	1
# slain	1
# twas	2
# chortled	1
# thought	2
# awhile	1
# time	1
# one	2
# bandersnatch	1
# its	1
# vorpal	2
# did	2
# mome	2
# stood	2
# long	1
# come	1
# rested	1
# that	2
# son	1
# whiffling	1
# took	1
# came	2
# wabe	2
# two	2
# callay	1
# sought	1
# slithy	2
# bite	1
# boy	1
# day	1
# were	2
# catch	1
# frumious	1
# wood	1
# flame	1
# head	1
# jubjub	1
# arms	1
# thou	1
# shun	1
# jabberwock	3
# jaws	1
# dead	1
# tumtum	1
# mimsy	2
# hast	1
# eyes	1
# beware	2
# raths	2
# went	2
# gyre	2
# left	1
# manxome	1
# claws	1
# brillig	2
# the	19
# galumphing	1
# blade	1
# callooh	1
# snicker	1
# snack	1
# burbled	1
# tree	1
# frabjous	1
# back	1
# his	2
# and	14
# joy	1
# hand	1
# outgrabe	2
# with	2
# borogoves	2
# beamish	1
