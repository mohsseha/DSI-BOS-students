# %%
def tree_build(elem, tree):
    if "node" not in tree:
        tree["node"] = elem
    else:
        if elem < tree["node"]:
            if "left" in tree:
                build2(elem, tree["left"])
            else:
                tree["left"] = {}
                tree["left"]["node"] = elem
        if elem >tree["node"]:
            if "right" in tree:
                build2(elem, tree["right"])
            else:
                tree["right"] = {}
                tree["right"]["node"] = elem
                
    return(tree)

# %%
# Build list and RANDOMIZE order
import random
l = list(range(1,100))
random.shuffle(l)

# Build tree
tree = {}
for elem in l:
    tree = tree_build(elem, tree)

# %%
print(l)
(tree)
# Out:
# [24, 22, 9, 5, 31, 36, 68, 8, 88, 96, 47, 6, 70, 97, 2, 34, 73, 55, 82, 75, 42, 81, 85, 33, 74, 13, 35, 29, 67, 50, 84, 78, 95, 86, 23, 37, 10, 26, 18, 11, 3, 87, 52, 57, 71, 83, 27, 48, 38, 46, 79, 66, 25, 51, 7, 65, 20, 60, 16, 69, 15, 98, 49, 53, 17, 92, 63, 91, 77, 76, 28, 99, 40, 44, 45, 80, 61, 1, 14, 21, 90, 4, 39, 43, 89, 58, 19, 54, 12, 41, 64, 56, 30, 93, 72, 62, 32, 59, 94]
# {'left': {'left': {'left': {'left': {'left': {'node': 1},
#      'node': 2,
#      'right': {'node': 3, 'right': {'node': 4}}},
#     'node': 5,
#     'right': {'left': {'node': 6, 'right': {'node': 7}}, 'node': 8}},
#    'node': 9,
#    'right': {'left': {'node': 10,
#      'right': {'node': 11, 'right': {'node': 12}}},
#     'node': 13,
#     'right': {'left': {'left': {'left': {'node': 14}, 'node': 15},
#       'node': 16,
#       'right': {'node': 17}},
#      'node': 18,
#      'right': {'left': {'node': 19}, 'node': 20, 'right': {'node': 21}}}}},
#   'node': 22,
#   'right': {'node': 23}},
#  'node': 24,
#  'right': {'left': {'left': {'left': {'node': 25},
#     'node': 26,
#     'right': {'node': 27, 'right': {'node': 28}}},
#    'node': 29,
#    'right': {'node': 30}},
#   'node': 31,
#   'right': {'left': {'left': {'left': {'node': 32}, 'node': 33},
#     'node': 34,
#     'right': {'node': 35}},
#    'node': 36,
#    'right': {'left': {'left': {'left': {'node': 37,
#        'right': {'node': 38,
#         'right': {'left': {'node': 39}, 'node': 40, 'right': {'node': 41}}}},
#       'node': 42,
#       'right': {'left': {'left': {'node': 43},
#         'node': 44,
#         'right': {'node': 45}},
#        'node': 46}},
#      'node': 47,
#      'right': {'left': {'left': {'node': 48, 'right': {'node': 49}},
#        'node': 50,
#        'right': {'left': {'node': 51},
#         'node': 52,
#         'right': {'node': 53, 'right': {'node': 54}}}},
#       'node': 55,
#       'right': {'left': {'left': {'node': 56},
#         'node': 57,
#         'right': {'left': {'left': {'left': {'node': 58,
#             'right': {'node': 59}},
#            'node': 60,
#            'right': {'left': {'node': 61, 'right': {'node': 62}},
#             'node': 63,
#             'right': {'node': 64}}},
#           'node': 65},
#          'node': 66}},
#        'node': 67}}},
#     'node': 68,
#     'right': {'left': {'left': {'node': 69},
#       'node': 70,
#       'right': {'left': {'node': 71, 'right': {'node': 72}},
#        'node': 73,
#        'right': {'left': {'left': {'node': 74},
#          'node': 75,
#          'right': {'left': {'left': {'left': {'node': 76}, 'node': 77},
#            'node': 78,
#            'right': {'node': 79, 'right': {'node': 80}}},
#           'node': 81}},
#         'node': 82,
#         'right': {'left': {'left': {'node': 83}, 'node': 84},
#          'node': 85,
#          'right': {'node': 86, 'right': {'node': 87}}}}}},
#      'node': 88,
#      'right': {'left': {'left': {'left': {'left': {'left': {'node': 89},
#           'node': 90},
#          'node': 91},
#         'node': 92,
#         'right': {'node': 93, 'right': {'node': 94}}},
#        'node': 95},
#       'node': 96,
#       'right': {'node': 97, 'right': {'node': 98, 'right': {'node': 99}}}}}}}}}

# %%
# Depth-first search
def finditem(tree, entry):
    flag = False
    
    if entry == tree["node"]:
        flag = True
    
    if entry < tree["node"]:
        if "left" in tree:
            flag = finditem(tree["left"], entry)
    if entry > tree["node"]:
        if "right" in tree:
            flag = finditem(tree["right"], entry)
     
    return(flag)

# %%
# Check
for i in range(150):
    print(i, finditem(tree, i))
# Out:
# 0 False
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# 10 True
# 11 True
# 12 True
# 13 True
# 14 True
# 15 True
# 16 True
# 17 True
# 18 True
# 19 True
# 20 True
# 21 True
# 22 True
# 23 True
# 24 True
# 25 True
# 26 True
# 27 True
# 28 True
# 29 True
# 30 True
# 31 True
# 32 True
# 33 True
# 34 True
# 35 True
# 36 True
# 37 True
# 38 True
# 39 True
# 40 True
# 41 True
# 42 True
# 43 True
# 44 True
# 45 True
# 46 True
# 47 True
# 48 True
# 49 True
# 50 True
# 51 True
# 52 True
# 53 True
# 54 True
# 55 True
# 56 True
# 57 True
# 58 True
# 59 True
# 60 True
# 61 True
# 62 True
# 63 True
# 64 True
# 65 True
# 66 True
# 67 True
# 68 True
# 69 True
# 70 True
# 71 True
# 72 True
# 73 True
# 74 True
# 75 True
# 76 True
# 77 True
# 78 True
# 79 True
# 80 True
# 81 True
# 82 True
# 83 True
# 84 True
# 85 True
# 86 True
# 87 True
# 88 True
# 89 True
# 90 True
# 91 True
# 92 True
# 93 True
# 94 True
# 95 True
# 96 True
# 97 True
# 98 True
# 99 True
# 100 False
# 101 False
# 102 False
# 103 False
# 104 False
# 105 False
# 106 False
# 107 False
# 108 False
# 109 False
# 110 False
# 111 False
# 112 False
# 113 False
# 114 False
# 115 False
# 116 False
# 117 False
# 118 False
# 119 False
# 120 False
# 121 False
# 122 False
# 123 False
# 124 False
# 125 False
# 126 False
# 127 False
# 128 False
# 129 False
# 130 False
# 131 False
# 132 False
# 133 False
# 134 False
# 135 False
# 136 False
# 137 False
# 138 False
# 139 False
# 140 False
# 141 False
# 142 False
# 143 False
# 144 False
# 145 False
# 146 False
# 147 False
# 148 False
# 149 False
